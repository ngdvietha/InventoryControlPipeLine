# %%
#import necessary libraries
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.processed.forecast import moving_average_forecast

data = [100, 120, 130, 90, 110, 115]

forecast = moving_average_forecast(data, window=3, forecast_horizon=5)

print(forecast)
# Out:
# [np.float64(105.0), np.float64(110.0), np.float64(110.0), np.float64(108.33333333333333), np.float64(109.44444444444444)]

# %%
from src.processed.forecast import simple_exponential_smoothing

data = [100, 120, 130, 90, 110]

fitted, forecast = simple_exponential_smoothing(data, alpha=0.3, forecast_horizon=3)

print("Fitted:", fitted)
print("Forecast:", forecast)
# Out:
# Fitted: [100, 100.0, 106.0, 113.19999999999999, 106.23999999999998]
# Forecast: [107.36799999999998, 107.36799999999998, 107.36799999999998]
